# %%
import pandas as pd
import numpy as np
import re
from fuzzywuzzy import process, fuzz
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
df = pd.read_csv("Downloads/ground_vehicles.csv")

# %% [markdown]
# Let's fix the column names

# %%
df.columns = df.columns.str.replace(' ', '_')
df["Contract_Number"] = df["Contract_Number_(IDVPIID)"]
df["Award_Number"] = df["Award_Number_(PIID)"]

# %% [markdown]
# There seems to be some extraneous data- medical, VA, etc. Let's clean some of that out.
#
# Let's start with removing any rows that don't pertain to DoD.

# %%
df["contract_ag"] = df['Contracting_Agency'].str.replace(r'\W+', '', regex=True)

# %%
df['DoD'] = (df['contract_ag'].str.contains('USDepartmentofDefenseDoD', na=False))

df = df[df.DoD == True]

# %% [markdown]
# This data also contains information from FY21, but we are only interested in FY16-FY21

# %%
df = df[df.Fiscal_Year != 2021]

# %% [markdown]
# Now, lets pull out and label anything that mentions Bradley, Abrams, or Stryker in the Title.

# %% [markdown]
# Who is working on GCS?
#
# Lets search for specific terms and tag each of the three vehicles:

# %%
df['Title'] = df['Title'].str.lower()

df['stryker'] =  np.where(df.Title.str.contains("stryker"), 1,
                   np.where(df.Title.str.contains("armored personnel carrier"),1,  np.NaN))
                        
df['abrams'] =   np.where(df.Title.str.contains("abrams"),1,      
                   np.where(df.Title.str.contains("tank"),1, np.NaN))    
                         
df['bradley']  = np.where(df.Title.str.contains("bradley"), 1,
                   np.where(df.Title.str.contains("fighting vehicle"), 1,  np.NaN))     
                             
df = df.dropna(subset=['stryker','abrams','bradley'], how='all')

df['stryker'] = df['stryker'].fillna(0)
df['abrams'] = df['abrams'].fillna(0)
df['bradley'] = df['bradley'].fillna(0)

len(df.Vendor__Name.unique())
# Out:
# 273

# %% [markdown]
# There also seems to be a lot of medical data here- we need to remove it manually bc there is a Stryker vendor that makes medical equipment. We can use the PSC_Name codes to filter things out.
#
# If it leads with an alphabetic character, it signifies a specific category; similarly, if it is a 4-digit code, the first two digits represent a group.
#
# Finally, I want to scrub any reference to the word "Medical" for anything that has a subcategory in medical.

# %%
df['psc'] = df["PSC_Name"].str.extract(r'(\w+)', expand=False)
df['abb'] = df["psc"].str.extract(r'(\D+)', expand=False)
df['code'] = df["psc"].str.extract(r'(\d{4})', expand=False)
df['pcode'] = df['code'].str.extract(r'(\d{2})', expand=False)

print(df[['PSC_Name','psc', 'abb', 'code', 'pcode']])
# Out:
#                                                 PSC_Name   psc  abb  code  \
# 315                          (53) HARDWARE AND ABRASIVES    53  NaN   NaN
# 750    (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECH...  R425    R   NaN
# 755    (J099) MAINT/REPAIR/REBUILD OF EQUIPMENT- MISC...  J099    J   NaN
# 756    (J065) MAINT/REPAIR/REBUILD OF EQUIPMENT- MEDI...  J065    J   NaN
# 760    (6515) MEDICAL AND SURGICAL INSTRUMENTS, EQUIP...  6515  NaN  6515
# ...                                                  ...   ...  ...   ...
# 53089           (6640) LABORATORY EQUIPMENT AND SUPPLIES  6640  NaN  6640
# 53090  (6515) MEDICAL AND SURGICAL INSTRUMENTS, EQUIP...  6515  NaN  6515
# 53091           (6640) LABORATORY EQUIPMENT AND SUPPLIES  6640  NaN  6640
# 53092           (6640) LABORATORY EQUIPMENT AND SUPPLIES  6640  NaN  6640
# 53093           (6640) LABORATORY EQUIPMENT AND SUPPLIES  6640  NaN  6640
#
#       pcode
# 315     NaN
# 750     NaN
# 755     NaN
# 756     NaN
# 760      65
# ...     ...
# 53089    66
# 53090    65
# 53091    66
# 53092    66
# 53093    66
#
# [4735 rows x 5 columns]

# %%
df = df[df.abb != 'AN'] #Health R&D
df = df[df.abb != 'Q'] #Medical
df = df[df.pcode != 65] #Medical
df = df[df.psc != 65] #Medical

df['med'] = (df['PSC_Name'].str.contains('MEDICAL', na=False))
df = df[df.med == False]

df['hos'] = (df['PSC_Name'].str.contains('HOSPITAL', na=False))
df = df[df.hos == False]

df['lab'] = (df['PSC_Name'].str.contains('LABORATORY', na=False))
df = df[df.lab == False]

df['endo'] = (df['Title'].str.contains('endoscopy', na=False))
df = df[df.endo == False]

df['op'] = (df['PSC_Name'].str.contains('OPHTHALMIC', na=False))                #troubleshoot later, this should have been taken out ? 
df = df[df.op == False]

# %% [markdown]
# Run a quick test to make sure the titles make sense

# %%
df.Title.sample(10)
# Out:
# 34099    contract w56hzv-17-c-0067 is a sole source con...
# 48295    spare parts needed in support of the digital e...
# 10041    431 tension devices, left side for m1 abrams w...
# 39789    abrams expedited active protection systems (ex...
# 33777    work directive r-11-13-02 award for retrofit a...
# 43438    mod to ses/c4isr/cm task order under the syste...
# 41138                      stryker contractor test support
# 38721    transmission (hydro-mechanically propelled tra...
# 41958    systems technical support and sustainment syst...
# 33500          stryker logistics engineering support (les)
# Name: Title, dtype: object

# %% [markdown]
# Normalizing Vendors --  We will start by removing spaces, special characters, and strings like LLC or LTD from the end.

# %%
df["ven_name"] = df['Vendor__Name'].str.replace(r'\W+', '', regex=True)
df['ven_name'] = df['ven_name'].apply(str.lower)

df["ven_name"] = df['ven_name'].str.replace('(llc|inc|co|companylimited|ltda|corporation|ltd|corp|company|incorporated|limitedliabilitycompany|limitedliability)$', '', regex=True)

# %% [markdown]
# From here, we will do fuzzy matching to group vendors.

# %%
unique_ven = df.ven_name.unique()

score_sort = [(x,) + i
             for x in unique_ven
             for i in process.extract(x, unique_ven, scorer=fuzz.partial_ratio)]

#Create a dataframe from the tuples
similarity_sort = pd.DataFrame(score_sort, columns=['ven_sort','match_sort','score_sort'])

# %% [markdown]
# Let's collect only those with high sorting score. (after analysis, only those at 100% were correct)

# %%
similarity_sort['sorted_ven_sort'] = np.minimum(similarity_sort['ven_sort'], similarity_sort['match_sort'])

high_score_sort = similarity_sort[(similarity_sort['score_sort'] >= 100) &
                (similarity_sort['ven_sort'] !=  similarity_sort['match_sort']) &
                (similarity_sort['sorted_ven_sort'] != similarity_sort['match_sort'])]
high_score_sort = high_score_sort.drop('sorted_ven_sort',axis=1).copy()

high_score_sort.groupby(['ven_sort','score_sort']).agg(
                        {'match_sort': ', '.join}).sort_values(
                        ['score_sort'], ascending=False)
# Out:
#                                                                                                match_sort
# ven_sort                                    score_sort
# branchsconsulting                           100                                                       nch
# classicsitesolutions                        100                                                       sit
# cummins                                     100                                           cumminsmidsouth
# gan                                         100         nationalcenterfordefensemanufacturingandmachin...
# generaldynamicslandsystem                   100         generaldynamicslandsystems, generaldynamicslan...
# generaldynamicslandsystems                  100         generaldynamicslandsystemscustomerservicesuppo...
# lockheedmartin                              100         lockheedmartinrotarymissionsystemslmrms, rayth...
# macematerialacquisitioncontractingequipment 100                                                       sit
# michigantechnologicaluniversity             100                                                       sit
# raytheon                                    100                 raytheonlockheedmartinjavelinjointventure
# saab                                        100                                             saabbarracuda
# sit                                         100                                             ssitechnology
# stryker                                     100                                              strykersales

# %% [markdown]
# Let's replace these values in the df

# %%
df['ven_name'] = df['ven_name'].replace({'lockheedmartinrotarymissionsystemslmrms':'lockheedmartin',
                                        'generaldynamicslandsystemscustomerservicesupport' : 'generaldynamicslandsystems',
                                        'generaldynamicslandsystemscanada' :  'generaldynamicslandsystems',
                                         'generaldynamicslandsystemss' : 'generaldynamicslandsystems',
                                         'generaldynamicslandsystemssforceprotection' : 'generaldynamicslandsystems',
                                         'lockheedmartin'	: 'raytheonlockheedmartinjavelinjointventure',
                                         'raytheon' : 'raytheonlockheedmartinjavelinjointventure',
                                         'generaldynamicslandsystem': 'generaldynamicslandsystems',
                                         'saabbarracuda' : 'saab',
                                         'optexsystemsholdings': 'optexsystems',
                                         'cumminsmidsouth': 'cummins',
                                        }, regex=True)
ven_list = sorted(df.ven_name.unique())
len(ven_list)
# Out:
# 243

# %% [markdown]
# 264 unique vendors. Lets also clean up the Top Vendor Name list.

# %%
df["ven_tname"] = df['Vendor__Top_Name'].str.replace(r'\W+', '', regex=True)
df['ven_tname'] = df['ven_tname'].apply(str.lower)

df["ven_tname"] = df['ven_tname'].str.replace('(llc|inc|co|companylimited|ltda|corporation|ltd|corp|company|incorporated|limitedliabilitycompany|limitedliability)$', '', regex=True)


unique_vent = df.ven_tname.unique()

score_sort = [(x,) + i
             for x in unique_vent
             for i in process.extract(x, unique_vent, scorer=fuzz.partial_ratio)]

#Create a dataframe from the tuples
similarity_sort = pd.DataFrame(score_sort, columns=['vent_sort','match_sort','score_sort'])

similarity_sort['sorted_vent_sort'] = np.minimum(similarity_sort['vent_sort'], similarity_sort['match_sort'])

high_score_sort = similarity_sort[(similarity_sort['score_sort'] >= 95) &
                (similarity_sort['vent_sort'] !=  similarity_sort['match_sort']) &
                (similarity_sort['sorted_vent_sort'] != similarity_sort['match_sort'])]
high_score_sort = high_score_sort.drop('sorted_vent_sort',axis=1).copy()

high_score_sort.groupby(['vent_sort','score_sort']).agg(
                        {'match_sort': ', '.join}).sort_values(
                        ['score_sort'], ascending=False)
# Out:
#                                                                                                match_sort
# vent_sort                                   score_sort
# apiheattransferparent                       100                                                       att
# att                                         100                         battlecreekconstruction, plattson
# branchsconsulting                           100                                                       nch
# classicsitesolutions                        100                                                       sit
# gan                                         100         nationalcenterfordefensemanufacturingandmachin...
# generaldynamics                             100                                 generaldynamicslandsystem
# helixacquisitionholdings                    100                                                       sit
# lockheedmartin                              100                   lockheedmartinrotarymissionsystemslmrms
# macematerialacquisitioncontractingequipment 100                                                       sit
# michigantechnologicaluniversity             100                                                       sit
# dsmanufacturing                             97                                      highlandmanufacturing

# %%
df['ven_tname'] = df['ven_tname'].replace({'generaldynamics': 'generaldynamicslandsystem',
                                           'lockheedmartinrotarymissionsystemslmrms' : 'lockheedmartin',
                                            'strykerorthopaedics' : 'stryker',
                                           'strykerinternationalholdings' : 'stryker',
                                           'strykercommunications' :'stryker',
                                           'strykergmbhcokg' : 'stryker',
                                           'strykersales' : 'stryker',
                                           'strykersustainabilitysolutions':'stryker',
                                           'strykeruklimited' : 'stryker',
                                           'strykerbv' : 'stryker'
                                        }, regex=True)
ven_list = sorted(df.ven_tname.unique())
len(ven_list)
# Out:
# 230

# %% [markdown]
# Missing Vendors?

# %%
df[df['ven_name'].isna()] #No Missing Vendors
# Out:
# Empty DataFrame
# Columns: [ID, Contract_Number_(IDVPIID), Award_Number_(PIID), Modification_Number, Fiscal_Year, Title, Awarded_Amount, Contracting_Office, Contracting_Agency, Place_of_Performance_State, Place_of_Performance_City, Vendor__Name, Vendor__Top_Name, PSC_Name, Contract_Number, Award_Number, contract_ag, DoD, stryker, abrams, bradley, psc, abb, code, pcode, med, hos, lab, endo, op, ven_name, ven_tname]
# Index: []
#
# [0 rows x 32 columns]

# %% [markdown]
# Let's look at where the money is going! We can do this by examining the PSC_Name which shows us the category the purchase is charged to. Everything will either have a letter (Abb) or # (code); pcode shows the purchase grouping.
#
# Let's start by cleaning NaNs.

# %%
df[df['PSC_Name'].isna()]
# Out:
#               ID Contract_Number_(IDVPIID)   Award_Number_(PIID)  \
# 26903  461586923                       NaN  W56HZV17C0067_P00056
# 32370  552163413                       NaN  W56HZV17C0067_P00074
# 34954  555097230                       NaN  W56HZV17C0067_P00077
# 35097  558538537                       NaN  W56HZV17C0067_P00079
# 35342  561625423                       NaN         SPE7L519V2040
# 38506  580334521                       NaN  W56HZV17C0067_P00088
#
#       Modification_Number  Fiscal_Year                 Title  Awarded_Amount  \
# 26903                 NaN         2018            abrams sts             NaN
# 32370                 NaN         2019            abrams sts             NaN
# 34954                 NaN         2019            abrams sts             NaN
# 35097                 NaN         2019            abrams sts             NaN
# 35342                 NaN         2019  plug, m1a1 tank barr             NaN
# 38506                 NaN         2019            abrams sts             NaN
#
#                             Contracting_Office  \
# 26903  ACC Warren Contracting Center (ACC-WRN)
# 32370  ACC Warren Contracting Center (ACC-WRN)
# 34954  ACC Warren Contracting Center (ACC-WRN)
# 35097  ACC Warren Contracting Center (ACC-WRN)
# 35342           Defense Logistics Agency (DLA)
# 38506  ACC Warren Contracting Center (ACC-WRN)
#
#                    Contracting_Agency Place_of_Performance_State  ...  abb  \
# 26903  US Department of Defense (DoD)                        NaN  ...  NaN
# 32370  US Department of Defense (DoD)                        NaN  ...  NaN
# 34954  US Department of Defense (DoD)                        NaN  ...  NaN
# 35097  US Department of Defense (DoD)                        NaN  ...  NaN
# 35342  US Department of Defense (DoD)                        NaN  ...  NaN
# 38506  US Department of Defense (DoD)                        NaN  ...  NaN
#
#       code pcode    med    hos    lab   endo     op  \
# 26903  NaN   NaN  False  False  False  False  False
# 32370  NaN   NaN  False  False  False  False  False
# 34954  NaN   NaN  False  False  False  False  False
# 35097  NaN   NaN  False  False  False  False  False
# 35342  NaN   NaN  False  False  False  False  False
# 38506  NaN   NaN  False  False  False  False  False
#
#                           ven_name                  ven_tname
# 26903  generaldynamicslandsystemss  generaldynamicslandsystem
# 32370  generaldynamicslandsystemss  generaldynamicslandsystem
# 34954  generaldynamicslandsystemss  generaldynamicslandsystem
# 35097  generaldynamicslandsystemss  generaldynamicslandsystem
# 35342                   transhield                 transhield
# 38506  generaldynamicslandsystemss  generaldynamicslandsystem
#
# [6 rows x 32 columns]

# %% [markdown]
# Abrams STS -- Found a posting for this actually as R425. https://govtribe.com/opportunity/federal-contract-opportunity/abrams-system-technical-support-sts-and-sustainment-system-technical-support-ssts-follow-on-w56hzv20r0216
#
# for the plug -- lets find the code for plug in what we have (surely there are other plugs!)

# %%
df.at[35342,'PSC_Name'] = '59'
df.at[26903,'PSC_Name'] = 'R'
df.at[32370,'PSC_Name'] = 'R'
df.at[34954,'PSC_Name'] = 'R'
df.at[35097,'PSC_Name'] = 'R'
df.at[38506,'PSC_Name'] = 'R'

# %%
plug_test = df[df['Title'].str.contains('abrams sts')]

plug_test[['Title', 'PSC_Name']].head(30)
# Out:
#                                                    Title  \
# 1039         abrams sts work directives - adding funding
# 7474   the purpose of mod p86 to contract w56hzv-13-c...
# 10065  the purpose of modification p00099 is to incor...
# 11198  the purpose of this modification is to increas...
# 16465  igf::ot::igf. base award of abrams sts/ssts fy...
# 18705  igf::ot::igf this modification adds 2 works di...
# 19527  igf::ot::igf this modification adds 4 work dir...
# 20995  igf::ot::igf this is a sole source contract to...
# 22441  administrative change to paying office. abrams...
# 23133  abrams sts dsests ulo to de-obligate excess funds
# 23991                                abrams sts for usmc
# 25439             option excerise for abrams sts program
# 26903                                         abrams sts
# 27665                                         abrams sts
# 29822                    abrams sts term work directives
# 32058            option exercise for abrams sts efforts.
# 32090                   abrams sts/ssts option exercises
# 32274                                         abrams sts
# 32370                                         abrams sts
# 32559            option exercise for abrams sts efforts.
# 34954                                         abrams sts
# 35097                                         abrams sts
# 35113                                         abrams sts
# 35293                                         abrams sts
# 35457  abrams sts. sole source to general dynamics la...
# 35458  abrams sts. sole source to gdls land systems. ...
# 35460  exercise option hours for abrams sts/ssts supp...
# 37156  abrams sts. logistics and services work direct...
# 37684     abrams sts funding increase and pop extension.
# 38506                                         abrams sts
#
#                                                 PSC_Name
# 1039   (2350) COMBAT, ASSAULT, AND TACTICAL VEHICLES,...
# 7474   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECH...
# 10065  (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECH...
# 11198  (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECH...
# 16465  (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECH...
# 18705  (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECH...
# 19527  (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECH...
# 20995  (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECH...
# 22441  (L025) TECHNICAL REPRESENTATIVE- VEHICULAR EQU...
# 23133  (5998) ELECTRICAL AND ELECTRONIC ASSEMBLIES, B...
# 23991  (R) SUPPORT (PROFESSIONAL/ADMINISTRATIVE/MANAG...
# 25439  (R) SUPPORT (PROFESSIONAL/ADMINISTRATIVE/MANAG...
# 26903                                                  R
# 27665  (R) SUPPORT (PROFESSIONAL/ADMINISTRATIVE/MANAG...
# 29822  (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECH...
# 32058  (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECH...
# 32090  (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECH...
# 32274  (R) SUPPORT (PROFESSIONAL/ADMINISTRATIVE/MANAG...
# 32370                                                  R
# 32559  (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECH...
# 34954                                                  R
# 35097                                                  R
# 35113  (R) SUPPORT (PROFESSIONAL/ADMINISTRATIVE/MANAG...
# 35293  (R) SUPPORT (PROFESSIONAL/ADMINISTRATIVE/MANAG...
# 35457  (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECH...
# 35458  (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECH...
# 35460  (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECH...
# 37156  (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECH...
# 37684  (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECH...
# 38506                                                  R

# %% [markdown]
# Let's smanipulate the PSC_Name. The first character identifies categories of spending, and if there are four digits, the first two specify groups of spending.

# %%
def extract_code(row):
    code = str(row['psc'])
    if (code[0].isalpha()):
        # TODO: fix to stop when encountering the first number
        # return ''.join([c for c in code if c.isalpha()])
        return code[:1]
    else:
        return code[:2]

# %%
df['psc'] = df["PSC_Name"].str.extract(r'(\w+)', expand=False)

# %%
df['code'] = df.apply(extract_code, axis=1)

# %%
df[['psc', 'code']].head(10)
# Out:
#       psc code
# 315    53   53
# 750  R425    R
# 755  J099    J
# 797  2520   25
# 807  1290   12
# 867  6150   61
# 930  2355   23
# 946  4220   42
# 970  4810   48
# 971  H910    H

# %% [markdown]
# Before we dive into comparing, lets consolidate stryker, abrams, and bradley into one column, GCS.
#
# First lets check the max to see if any rows mentioned multiple.

# %%
df['GCSsum']= df['stryker']+df['bradley']+df['abrams']
df.GCSsum.describe()
# Out:
# count    1647.000000
# mean        1.126897
# std         0.428679
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         3.000000
# Name: GCSsum, dtype: float64

# %% [markdown]
# Some rows have both, lets just name that "general".

# %%
df['GCS'] = 'test'
df.loc[df['abrams'] == 1, 'GCS'] = 'abrams'
df.loc[df['stryker'] == 1, 'GCS'] = 'stryker'
df.loc[df['bradley'] == 1, 'GCS'] = 'bradley'
df.loc[df['GCSsum'] >= 2, 'GCS'] = 'general'

df.GCS.describe()
# Out:
# count       1647
# unique         4
# top       abrams
# freq         742
# Name: GCS, dtype: object

# %% [markdown]
# Let's remove NAs from Awarded Amount so that we can do some overview stats.

# %%
df['Awarded_Amount'] = df['Awarded_Amount'].fillna(0)

df['Awarded_Amount'].describe()
# Out:
# count    1.647000e+03
# mean     4.792985e+06
# std      3.245477e+07
# min     -1.189190e+07
# 25%      0.000000e+00
# 50%      8.182132e+04
# 75%      9.419590e+05
# max      7.144557e+08
# Name: Awarded_Amount, dtype: float64

# %% [markdown]
# Several entries have $0 as the cost- is this accurate or is this data missing? (most likely missing)

# %% [markdown]
# Let's replace the 0's with the medians of other billings in the same category (grouping by initial PSC groups).

# %%
df['medpsc'] = df.groupby('code')['Awarded_Amount'].transform('median')

def change_awrd(row):
    awrd = row['Awarded_Amount']
    if awrd == 0:
        return row['medpsc']
    else:
        return awrd

# %%
df['Awarded_Amount'] = df.apply(change_awrd, axis=1)

df['Awarded_Amount'].describe()
# Out:
# count    1.647000e+03
# mean     4.824561e+06
# std      3.245081e+07
# min     -1.189190e+07
# 25%      1.379926e+04
# 50%      1.412120e+05
# 75%      9.882935e+05
# max      7.144557e+08
# Name: Awarded_Amount, dtype: float64

# %%
df['award_gain']= df.loc[df['Awarded_Amount'] >= 0,['Awarded_Amount']]
df['award_loss']= df.loc[df['Awarded_Amount'] <= 0,['Awarded_Amount']]
df['award_gain'] = df['award_gain'].fillna(0)
df['award_loss'] = df['award_loss'].fillna(0)


print(df[['award_gain', 'award_loss']])
# Out:
#        award_gain  award_loss
# 315      15455.00         0.0
# 750     141212.00         0.0
# 755      21060.00         0.0
# 797    3959584.86         0.0
# 807    1411695.25         0.0
# ...           ...         ...
# 49727    13998.48         0.0
# 49790        0.00   -526794.0
# 49793   258320.21         0.0
# 49794   141212.00         0.0
# 50255   205438.51         0.0
#
# [1647 rows x 2 columns]

# %% [markdown]
# Lets run a few SQL queries to get an idea of trends.

# %%
q1 = "SELECT GCS, sum(Awarded_Amount) as aa FROM df GROUP BY GCS ORDER BY aa desc;"
print(pysqldf(q1))
# Out:
#        GCS            aa
# 0   abrams  5.208164e+09
# 1  stryker  1.831839e+09
# 2  bradley  6.113595e+08
# 3  general  2.946899e+08

# %% [markdown]
# A preliminary view shows
#
# Abrams: 5.2b
# Stryker: 1.8b
# Bradley: .6b
# General: .2b

# %%
df.Awarded_Amount.sum()
# Out:
# 7946051988.264999

# %% [markdown]
# Let's look at the changes from year to year.

# %%
q2 = "SELECT GCS,Fiscal_Year, sum(Awarded_Amount) as aa FROM df GROUP BY GCS, Fiscal_Year ORDER BY aa desc;"
print(pysqldf(q2))
# Out:
#         GCS  Fiscal_Year            aa
# 0    abrams         2018  1.843133e+09
# 1    abrams         2019  1.641344e+09
# 2    abrams         2020  1.093988e+09
# 3   stryker         2019  5.198837e+08
# 4   stryker         2018  4.553002e+08
# 5    abrams         2017  4.423467e+08
# 6   stryker         2016  3.716759e+08
# 7   stryker         2017  3.358803e+08
# 8   bradley         2018  2.646469e+08
# 9    abrams         2016  1.873516e+08
# 10  bradley         2019  1.722531e+08
# 11  general         2020  1.495852e+08
# 12  stryker         2020  1.490990e+08
# 13  general         2019  1.098635e+08
# 14  bradley         2016  8.717802e+07
# 15  bradley         2020  7.079566e+07
# 16  general         2018  2.860599e+07
# 17  bradley         2017  1.648584e+07
# 18  general         2017  3.378858e+06
# 19  general         2016  3.256438e+06

# %% [markdown]
# Notes:
#
# Abrams dramatically increased between FY17 and FY18 (43m -> 183m);
# Stryker consistently uses between 15m and 51m
# Bradley's range is between 2m and 26m.
#
# General GCS funds are between 324,000 and 15m. 2019 and 2020 saw the highest growth for this category.

# %% [markdown]
# Let's now look at the money received and rescinded each year.

# %%
q3 = "SELECT GCS,Fiscal_Year, sum(award_gain) as gain, sum(award_loss) as loss FROM df GROUP BY GCS, Fiscal_Year ORDER BY GCS desc;"
print(pysqldf(q3))
# Out:
#         GCS  Fiscal_Year          gain         loss
# 0   stryker         2016  3.726073e+08   -931375.71
# 1   stryker         2017  3.500127e+08 -14132394.72
# 2   stryker         2018  4.604317e+08  -5131512.15
# 3   stryker         2019  5.322267e+08 -12342983.52
# 4   stryker         2020  1.503501e+08  -1251079.46
# 5   general         2016  3.271318e+06    -14879.76
# 6   general         2017  3.539501e+06   -160643.19
# 7   general         2018  3.064302e+07  -2037023.06
# 8   general         2019  1.134480e+08  -3584478.02
# 9   general         2020  1.597211e+08 -10135979.75
# 10  bradley         2016  8.858478e+07  -1406751.63
# 11  bradley         2017  1.883246e+07  -2346620.41
# 12  bradley         2018  2.662070e+08  -1560063.60
# 13  bradley         2019  1.751764e+08  -2923307.89
# 14  bradley         2020  7.613715e+07  -5341494.98
# 15   abrams         2016  1.877910e+08   -439401.76
# 16   abrams         2017  4.437921e+08  -1445455.66
# 17   abrams         2018  1.848668e+09  -5534961.62
# 18   abrams         2019  1.653508e+09 -12163329.17
# 19   abrams         2020  1.114605e+09 -20617491.49

# %% [markdown]
# Many gains and losses each year. (will look better as a graph!)

# %%
q4 = "SELECT Contract_Number, ven_name, GCS, sum(award_gain) as gain, sum(award_loss) as loss FROM df GROUP BY Contract_Number, ven_name, GCS ORDER BY gain desc;"
pysqldf(q4).head(10)
# Out:
#   Contract_Number                                   ven_name      GCS  \
# 0   W56HZV18D0012                generaldynamicslandsystemss   abrams
# 1            None                generaldynamicslandsystemss   abrams
# 2   W56HZV17DB020                generaldynamicslandsystemss  stryker
# 3            None                  baesystemslandarmamentslp  bradley
# 4            None                      systemsdrssustainment   abrams
# 5            None                  baesystemslandarmamentslp  general
# 6   W56HZV16D0060                generaldynamicslandsystemss  stryker
# 7   W909MY19D0015  raytheonlockheedmartinjavelinjointventure   abrams
# 8   W56HZV16D0025                generaldynamicslandsystemss  stryker
# 9            None                generaldynamicslandsystemss  stryker
#
#            gain         loss
# 0  2.463614e+09   -427884.08
# 1  1.243312e+09 -31857765.83
# 2  1.029713e+09   -960146.80
# 3  3.849932e+08  -8158618.51
# 4  3.066315e+08         0.00
# 5  2.216791e+08  -8120707.00
# 6  1.810125e+08         0.00
# 7  1.612287e+08         0.00
# 8  1.578012e+08  -1222753.00
# 9  1.364382e+08    -27519.00

# %%
q5 = "SELECT ven_name, GCS, sum(award_gain) as gain, sum(award_loss) as loss FROM df GROUP BY ven_name, GCS ORDER BY gain desc;"
pysqldf(q5).head(10)
# Out:
#                                     ven_name      GCS          gain  \
# 0                generaldynamicslandsystemss   abrams  3.952412e+09
# 1                generaldynamicslandsystemss  stryker  1.760390e+09
# 2                  baesystemslandarmamentslp  bradley  3.850301e+08
# 3                      systemsdrssustainment   abrams  3.066315e+08
# 4                  baesystemslandarmamentslp  general  2.216791e+08
# 5                        allisontransmission   abrams  2.159835e+08
# 6  raytheonlockheedmartinjavelinjointventure   abrams  1.901607e+08
# 7                             l3technologies  bradley  1.282998e+08
# 8                     honeywellinternational   abrams  1.274804e+08
# 9                   drsnetworkimagingsystems   abrams  1.041548e+08
#
#           loss
# 0 -32688430.45
# 1 -17631930.53
# 2  -8158618.51
# 3         0.00
# 4  -8120707.00
# 5   -998026.04
# 6     -9045.49
# 7   -946350.00
# 8         0.00
# 9    -52438.80

# %%
q6 = "SELECT Award_Number, ven_name, GCS, sum(award_gain) as gain, sum(award_loss) as loss FROM df GROUP BY Award_Number, ven_name, GCS ORDER BY Award_Number desc;"
pysqldf(q6).head(10)
# Out:
#        Award_Number                   ven_name      GCS        gain  \
# 0     W91ZRS19C5003       classicsitesolutions  bradley   782482.00
# 1  W91ZRS-19-C-5000        larosabuildinggroup  bradley     5490.00
# 2     W91QV116C0107   corenicconstructiongroup   abrams  1263320.38
# 3     W91CRB19C5007     northropgrummansystems   abrams  7666502.80
# 4     W91CRB17C5008   drsnetworkimagingsystems   abrams  6379092.66
# 5     W9136418F0160  westernmetalsupplycompany  general  1010777.77
# 6     W9133L17F0021             miraclesystems  stryker  1832078.71
# 7     W912QR19F0318        themasonhangergroup   abrams   457254.36
# 8     W912QR19F0171        themasonhangergroup   abrams    23924.95
# 9     W912PB20F3632        centraltexascollege  stryker     3848.86
#
#          loss
# 0        0.00
# 1        0.00
# 2 -1043622.43
# 3        0.00
# 4        0.00
# 5        0.00
# 6        0.00
# 7        0.00
# 8        0.00
# 9        0.00

# %%
pscdf = pd.read_csv("Downloads/psc.csv")

pscdf.columns = pscdf.columns.str.replace(' ', '_')

# %%
q7 = "SELECT p.PRODUCT_AND_SERVICE_CODE_NAME as psc, d.GCS, sum(d.award_gain) as ag, sum(d.award_loss) as al FROM df d LEFT JOIN pscdf p ON p.PSC_CODE=d.code GROUP BY psc, GCS ORDER BY ag desc;"
pysqldf(q7).head(5)
# Out:
#                                 psc      GCS            ag           al
# 0  MOTOR VEHICLES, CYCLES, TRAILERS   abrams  3.100645e+09 -19323017.47
# 1  MOTOR VEHICLES, CYCLES, TRAILERS  stryker  1.120275e+09  -6786025.13
# 2  SUPPORT SVCS (PROF, ADMIN, MGMT)   abrams  5.814455e+08 -15866376.12
# 3  MOTOR VEHICLES, CYCLES, TRAILERS  bradley  4.652386e+08  -6114478.83
# 4    COMM/DETECT/COHERENT RADIATION   abrams  2.949322e+08         0.00

# %% [markdown]
# Export for Tableau viz!

# %%
df.to_excel('Downloads\df1.xlsx',index=False)

# %% [markdown]
# Investigating interesting things!

# %% [markdown]
# Intersting thing 1: Fire Equipment?

# %%
pd.set_option('display.max_colwidth', None)

# %%
fire = df[df['code']=='12']

fire[['Title','PSC_Name','code']].head(10)
# Out:
#                                                                                                                                                                                    Title  \
# 807      * contract sprdl1-16-c-0015 o awarded 29 aug 13 to real-time laboratories, llc (small business) o 97 each, ccha with 100% option o m1 abrams tank o award amount: $1,564,965.02
# 4605                                                                                                                              contract for hardware to support the m1a1 abrams tank.
# 9188                                                                                                                                       usmc m1a1 tank commander single handle (tcsh)
# 10762                                                                     collimator, infinity in support of the m1 abrams tank. (nsn 1240-01-475-0276) procured under farf6.302 urgency
# 14958                    turret, power control nsn 1240-01-616-2555 in support of the m1 abrams tank. qty: 11; option: 11 (not exercised at time of award). first article test required.
# 23360                                                                     systems technical support for m1a1 abrams. modification to deobligate excess funds after completion of effort.
# 24544  incorporate and exercise option for engineering support for abrams full displacement control grip, travel, prototypes, and protector rws- abrams full displacement control grips.
# 28006                                                switchboard, fire control; nsn 1290-01-358-3928 in support of the m1 abrams tank. qty: 5 option: 5 (not exercised at time of award)
# 28386                                           switchboard, fire control; nsn 1290-01-600-4747 in support of the m1 abrams tank. qty: 263; option 263 (not exercised at time of award).
# 28989                                                      computer, fire control; nsn 1220-01-619-0117 in support of the m1 abrams tank. qty: 99, option 99 exercised at time of award.
#
#                                                PSC_Name code
# 807         (1290) MISCELLANEOUS FIRE CONTROL EQUIPMENT   12
# 4605      (1240) OPTICAL SIGHTING AND RANGING EQUIPMENT   12
# 9188                        (12) FIRE CONTROL EQUIPMENT   12
# 10762     (1240) OPTICAL SIGHTING AND RANGING EQUIPMENT   12
# 14958     (1240) OPTICAL SIGHTING AND RANGING EQUIPMENT   12
# 23360             (1230) FIRE CONTROL SYSTEMS, COMPLETE   12
# 24544             (1230) FIRE CONTROL SYSTEMS, COMPLETE   12
# 28006       (1290) MISCELLANEOUS FIRE CONTROL EQUIPMENT   12
# 28386       (1290) MISCELLANEOUS FIRE CONTROL EQUIPMENT   12
# 28989  (1220) FIRE CONTROL COMPUTING SIGHTS AND DEVICES   12

# %%
fire['psc'].value_counts()
# Out:
# 1240    12
# 1290     8
# 1220     3
# 1230     2
# 12       1
# Name: psc, dtype: int64

# %% [markdown]
# 1240: OPTICAL SIGHTING AND RANGING EQUIPMENT
#
# 1290:MISC FIRE CONT EQUIPMENT

# %%
fire2 = df[df['code']=='42']

fire2[['Title','PSC_Name','code']].head(10)
# Out:
#                                                      Title  \
# 946                               4532160749 stryker; auto
# 12182          4535894353 mcs woodland euro stryker system
# 20814       4538734939 radiation detector; stryker mounted
# 21007                             4538789931 stryker; auto
# 21030                 4538808534 stryker ecp phase 2 - 1.0
# 21316                 4538913759 stryker ecp phase 2 - 5.0
# 22213               4539288330 stryker ecp phase 2 - 11`.0
# 22263                         4538947161 mini stryker; aut
# 22500  4539399321 radiation detector; stryker mounted - mo
# 24565                       4539800966 stryker cover (mcv)
#
#                                             PSC_Name code
# 946    (4220) MARINE LIFESAVING AND DIVING EQUIPMENT   42
# 12182  (4220) MARINE LIFESAVING AND DIVING EQUIPMENT   42
# 20814  (4220) MARINE LIFESAVING AND DIVING EQUIPMENT   42
# 21007  (4220) MARINE LIFESAVING AND DIVING EQUIPMENT   42
# 21030  (4220) MARINE LIFESAVING AND DIVING EQUIPMENT   42
# 21316  (4220) MARINE LIFESAVING AND DIVING EQUIPMENT   42
# 22213  (4220) MARINE LIFESAVING AND DIVING EQUIPMENT   42
# 22263  (4220) MARINE LIFESAVING AND DIVING EQUIPMENT   42
# 22500  (4220) MARINE LIFESAVING AND DIVING EQUIPMENT   42
# 24565  (4220) MARINE LIFESAVING AND DIVING EQUIPMENT   42

# %%
fire2['psc'].value_counts()
# Out:
# 4220    20
# 4240     2
# 4210     2
# Name: psc, dtype: int64

# %% [markdown]
# Okay, we will rename this one as "Marine Lifesaving and Diving Equipment"; upon reading online, it is an attachment/improvement to the Stryker.

# %% [markdown]
# Digging into COMM/DETECT/COHERENT RADIATION

# %%
comm= df[df['code']=='58']

comm['psc'].value_counts()
# Out:
# 5855    29
# 5895     5
# Name: psc, dtype: int64

# %% [markdown]
# We also have some aerospace tags; my hypothesis is that it's a sub category and used in both tanks and airplanes.

# %%
air = df[df['code']=='16']

air[['Title','PSC_Name','code']].head(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Title  \
# 28311  the united states army aviation and missile command has a current effort to provide support to program executive office simulation, training and instrumentation, games for training. the prototype integration facility will build, integrate, deliver and install four stryker virtual collective trainer suites. the system specification requires soldiers being trained to use the virtual battle space 3 and army games for training gaming software packages. the hardware being acquired on 18-207 fulfills this requirement.
# 29683                                                                                                                                                                                                                                                                                                                                                                                                        mod to change quantity for the joint system integration laboratory customer for the stryker virtual collective training system.
# 29861                                                                                                                                                                                                                                                                                                                                                                                                                                                         material purchase in support of the stryker virtual collective trainer (svct).
# 32581                                                                                                                                                                                                    acquisition of a power control module (pcm) line replaceable unit (lru) interchangeable test adaptor (ita), system control box (scb) lru ita, and a turret power box (tpb) lru ita for a larson test station is necessary to perform manufacturing acceptance of the pcm, scb, and tpb circuitry assemblies on the bradley vehicle.
# 48998                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        mod to increase funding for stryker itn support
#
#                                                        PSC_Name code
# 28311  (1680) MISCELLANEOUS AIRCRAFT ACCESSORIES AND COMPONENTS   16
# 29683  (1680) MISCELLANEOUS AIRCRAFT ACCESSORIES AND COMPONENTS   16
# 29861  (1680) MISCELLANEOUS AIRCRAFT ACCESSORIES AND COMPONENTS   16
# 32581  (1680) MISCELLANEOUS AIRCRAFT ACCESSORIES AND COMPONENTS   16
# 48998  (1680) MISCELLANEOUS AIRCRAFT ACCESSORIES AND COMPONENTS   16

# %% [markdown]
# This is to train people on how to use Stryker. We will keep it (though should it be tagged as Training? )

# %% [markdown]
# Digging Deeper: Support Services

# %%
sprt = df[df['code']=='R']

sprt[['Title','PSC_Name','code']].head(20)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Title  \
# 750                                                                                                                                                                                                                                                                                                                                                                                                                                                                          the purpose of task order 0003 under contract w56hzv-09-a-a904 is to conduct a business case analysis (bca) evaluating different acquisition strategies relative to the abrams m1e3 modernization program. the bca will include a comparison of costs, timeliness, technical performance, risks, and programmatic issues associated with each acquisition strategy to include any factors that may influence the acquisition decision. modification 05 revises the administrating office from dcma huntsville to dcma orlando.
# 1611                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    igf::ot::igf modification to exercise option term i for milestone documentation supporting armored multi-purpose vehicle (ampv) and bradley engineering change proposal 2 (ecp 2)..
# 1977                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                bradley system technical support p00045
# 2602                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                bradley system technical support p00046
# 3327                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              igf::ct::igf decrease funding to remove expired funds for stryker program option year six
# 3668                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                bradley system technical support p00047
# 3749                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                igf::ot::igf pd mbts/pm abrams vehicle health management system network integraton evaluation 16.2/17.1
# 4013                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  igf::ot::igf stryker - nbcrv opt yr 1
# 4703                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           igf::ot::igf predictive analytics assessment for abrams tank
# 4755                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                igf::ct::igf to fund period 1 [fiscal year 2016 (fy16)] stryker wholesale supply in accordance with the contract terms established under stryker requirements contract w56hzv-16-d-0060
# 5306                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                the purpose of mod p00083 is to incorporate work directives 1023 (light weight structures) and 2070 (4id abrams fsr-conus) igf::ot::igf
# 5812                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          the purpose of mod p00084 to incorporate work directive 2078 (3id abrams fsr-conus) and to fix an admin pron error on clin 2076. igf::ot::igf
# 7009                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               the purpose of this modification is to extend the contract pop to 28 feb 2017 and fund wd 2086 for korea abrams fsr-oconus. igf::ot::igf
# 7474                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                the purpose of mod p86 to contract w56hzv-13-c-0017 is to add 3 work directives for abrams sts activities. igf::ot::igf
# 7615                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          igf::ot::igf repair of bradley tracked vehicles that were turned in from units at camp buehring, kuwait to technical manual -10/20 condition.
# 8621                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  the purpose of mod p00092 is to incorporate 3 abrams fsr work directives into contract w56hzv-13-c-0017. igf::ot::igf
# 9296                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            the purpose of this modification is to incorporate wd 2071 and wd 2083 for abrams fsr support. igf::ot::igf
# 9673   4605 - ngats - next generation automatic test set - limited user test 2. the ngats v6 is intended to be the newest off-platform automatic test system (ats) in the army integrated family of test equipment (ifte) product line that will provide the soldier a weapon system diagnostic tool. the ngats v6 is the replacement for the aging direct support system test set (dsests), by providing diagnostic support for current weapons system platforms supported by dsests which supports the abram and bradley platforms, the base shop test facility (bstf)(v)3, and bstf(v)5 which supports aviation and ground missile system. the bstf (v) 3, and bstf (v) 5 capability will each be added incrementally as pre-planned product improvements (p3i). up-armored m1085 medium tactical vehicle (mtv) as the prime mover. ngats was supported under the test support contract (tsc), which is a cost plus award fee indefinite delivery indefinite quantity (id-iq) contract w9115u-07-d-0003.
# 10065                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           the purpose of modification p00099 is to incorporate wd's 2001, 2016, 2084 and 2089 for the abrams sts effort. igf::ot::igf
# 11157                                                                                                                                          task order 4505 mounted soldier system (mss). mss will provide combat vehicle crewmembers and platform commanders with increased mission effectiveness on the network centric battlefield in the areas of c2, situational awareness, communications, force protection, survivability, mobility, and sustainability. the mss provides the combat vehicle commander increased capabilities to conduct offensive and defensive operations. the mss equips all combat vehicle crewmen (cvc) (including abrams, stryker, bradley, paladin, and future combat systems (fcs) platforms) and selected maneuver support (mspt) and maneuver sustainment (msus) soldiers who perform mounted missions. mss was supported under the test support contract (tsc), which is a cost plus award fee indefinite delivery indefinite quantity idiq contract w9115u-07-d-0003.
#
#                                                   PSC_Name code
# 750    (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R
# 1611   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R
# 1977   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R
# 2602   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R
# 3327   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R
# 3668   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R
# 3749   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R
# 4013   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R
# 4703   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R
# 4755                   (R499) SUPPORT- PROFESSIONAL: OTHER    R
# 5306   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R
# 5812   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R
# 7009   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R
# 7474   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R
# 7615         (R706) SUPPORT- MANAGEMENT: LOGISTICS SUPPORT    R
# 8621   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R
# 9296   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R
# 9673   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R
# 10065  (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R
# 11157  (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL    R

# %% [markdown]
# Lets address igf::ct::igf

# %%
df['igf'] =  np.where(df.Title.str.contains("igf::ct::igf"), 'ct',
                   np.where(df.Title.str.contains("igf::ot::igf"),"ot",  
                     np.where(df.Title.str.contains("igf::ot::igf"),"cl",        
                            np.NaN)))

# %%
df['igf'].value_counts()
# Out:
# nan    1439
# ot      189
# ct       19
# Name: igf, dtype: int64

# %% [markdown]
# What are the critical functions?

# %%
ct = df[df['igf']=='ct']

ct[['Contract_Number','Title','PSC_Name','code','igf','GCS']].head(20)
# Out:
#       Contract_Number  \
# 971     W91CRB14D0031
# 2497    W91CRB14D0031
# 2499    W91CRB14D0024
# 3327    W91CRB06D0015
# 4755    W56HZV16D0060
# 7296    W91CRB14D0024
# 10943   W91CRB14D0031
# 17075             NaN
# 19564   W31P4Q09A0021
# 20040             NaN
# 20353   W91CRB14D0031
# 20971             NaN
# 21675   W91CRB14D0031
# 22238   W91CRB14D0030
# 22545   W56HZV09AA905
# 26622   W31P4Q17D0005
# 26653   W31P4Q17D0005
# 37773             NaN
# 37971   W52P1J16D0020
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Title  \
# 971                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   igf::ct::igf incremental funding for aec's omnibus contract to support the stryker program base year - months 1-12
# 2497                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       igf::ct::igf incremental funding to support aec's omnibus contract that supports the stryker program. base year - months 1-12
# 2499                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     igf::ct::igf incremental funding to support aec's omnibus contract for the bradley and mrap programs base - labor (months 1-12)
# 3327                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           igf::ct::igf decrease funding to remove expired funds for stryker program option year six
# 4755                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             igf::ct::igf to fund period 1 [fiscal year 2016 (fy16)] stryker wholesale supply in accordance with the contract terms established under stryker requirements contract w56hzv-16-d-0060
# 7296                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               igf::ct::igf decrease funding on aec's omnibus contract that supports the stryker program. base - labor (months 1-12)
# 10943                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         igf::ct::igf incremental funding for aec's omnibus contract that supports the stryker program option year 1 - months 13-24
# 17075                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     igf::ct::igf stryker fuel spill cleanup on i-5
# 19564                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                igf::ct::igf exercise options; obsolescence support to custom and borders patrol; obsolescence support to bradley family of fighting vehicle; obsolescence support to amc counterfeit practices ipt
# 20040                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            igf::ct::igf. increase funding for the abrasive clean of stryker hulls.
# 20353                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        igf::ct::igf incremental funding and surge clin increase for atec's omnibus contract to support the ismed and stryker programs option year 1 - months 13-24
# 20971                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     igf::ct::igf stryker fuel spill cleanup on i-5
# 21675                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  igf::ct::igf incremental funding and surge clin transfer on aec's omnibus contract that supports the stryker program option year 2 - months 25-36
# 22238                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               igf::ct::igf incremental funding for aec's omnibus contract that supports the stryker and m109 programs option year 1 - months 13-24
# 22545  igf::ct::igf the purpose of this effort is to provide logistics operations support services to the program manager stryker brigade combat team warehousing facilities located at anniston army depot. assigned as the lead pm representative overseeing warehouse operations in support of stryker logistics support. responsible for integrating the ils elements to include maintenance, manpower/personnel, training, support equipment, supply, technical data, packaging and transportation to achieve comprehensive ils coverage for warehousing support. responsible for coordinating requirements throughout the organization to ensure sustainment needs are met for any activity requiring warehousing.
# 26622                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            igf::ct::igf funding for esm 17.05.05 "stryker support"
# 26653                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     igf::ct::igf funding for esm 17.05.05 rev a " stryker support"
# 37773                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       igf::ct::igf funding for esm 19.05.01 support for stryker crows tech refresh
# 37971                                                                                                                                                                                                                                                                                                                                                                                                                              this action will support a ccdc aviation and missile center project executed on behalf of the program executive office simulation, training and instrumentation peo stri, games for training gft in providing training for soldiers in the stryker brigade combat teams. igf::ct::igf
#
#                                                                                                      PSC_Name  \
# 971                                                                     (H910) OTHER QC/TEST/INSPECT- WEAPONS
# 2497                                                                    (H910) OTHER QC/TEST/INSPECT- WEAPONS
# 2499                                                                    (H910) OTHER QC/TEST/INSPECT- WEAPONS
# 3327                                                      (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL
# 4755                                                                      (R499) SUPPORT- PROFESSIONAL: OTHER
# 7296                                                                    (H910) OTHER QC/TEST/INSPECT- WEAPONS
# 10943                                                                   (H910) OTHER QC/TEST/INSPECT- WEAPONS
# 17075                                      (F108) ENVIRONMENTAL SYSTEMS PROTECTION- ENVIRONMENTAL REMEDIATION
# 19564                                                     (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL
# 20040  (J023) MAINT/REPAIR/REBUILD OF EQUIPMENT- GROUND EFFECT VEHICLES, MOTOR VEHICLES, TRAILERS, AND CYCLES
# 20353                                                                   (H910) OTHER QC/TEST/INSPECT- WEAPONS
# 20971                                      (F108) ENVIRONMENTAL SYSTEMS PROTECTION- ENVIRONMENTAL REMEDIATION
# 21675                                                                   (H910) OTHER QC/TEST/INSPECT- WEAPONS
# 22238                                                                   (H910) OTHER QC/TEST/INSPECT- WEAPONS
# 22545                                                     (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL
# 26622                             (AC24) R&D- DEFENSE SYSTEM: MISSILE/SPACE SYSTEMS (ENGINEERING DEVELOPMENT)
# 26653                             (AC24) R&D- DEFENSE SYSTEM: MISSILE/SPACE SYSTEMS (ENGINEERING DEVELOPMENT)
# 37773                                                     (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL
# 37971                                                                            (7035) ADP SUPPORT EQUIPMENT
#
#       code igf      GCS
# 971      H  ct  stryker
# 2497     H  ct  stryker
# 2499     H  ct  bradley
# 3327     R  ct  stryker
# 4755     R  ct  stryker
# 7296     H  ct  stryker
# 10943    H  ct  stryker
# 17075    F  ct  stryker
# 19564    R  ct  bradley
# 20040    J  ct  stryker
# 20353    H  ct  stryker
# 20971    F  ct  stryker
# 21675    H  ct  stryker
# 22238    H  ct  stryker
# 22545    R  ct  stryker
# 26622    A  ct  stryker
# 26653    A  ct  stryker
# 37773    R  ct  stryker
# 37971   70  ct  stryker

# %%
ot = df[df['igf']=='ot']

ot[['Contract_Number','Title','PSC_Name','code','igf','GCS']].head(20)
# Out:
#      Contract_Number  \
# 755              NaN
# 1611   W56HZV15AA901
# 2167   W58RGZ12D0089
# 2596   W56HZV13D0015
# 2828             NaN
# 3499             NaN
# 3749   N0002412D6404
# 3797             NaN
# 4013   W911SR10D0004
# 4223             NaN
# 4393             NaN
# 4630             NaN
# 4703   N0002412D6404
# 5030   FA300208D0016
# 5306             NaN
# 5812             NaN
# 6664   FA248713D0009
# 6668   FA248713D0009
# 6879             NaN
# 7009             NaN
#
#                                                                                                                                                                                                               Title  \
# 755                                                                                                                                                                       igf::ot::igf lgcc stryker neptune loa mod
# 1611                            igf::ot::igf modification to exercise option term i for milestone documentation supporting armored multi-purpose vehicle (ampv) and bradley engineering change proposal 2 (ecp 2)..
# 2167                                                                                                       igf::ot::igf task order 0538- stryker wireless internal combustion engine (wice)adapter/extension cables
# 2596                                                                                        igf::ot::igf cls/training services for m1a1 tanks and m88 recovery vehicles for the government of iraq for jan-dec 2016
# 2828                                                                                                                                               igf::ot::igf preventative maintenance for stryker ambulance cots
# 3499            igf::ot::igf; modification to determine the feasibility of integrating a sample probe onto the ngcd 3 (aka. multi-sample identifier) system and possible future integration onto the stryker nbcrv.
# 3749                                                                                                        igf::ot::igf pd mbts/pm abrams vehicle health management system network integraton evaluation 16.2/17.1
# 3797  igf::ot::igf this contract is for up to three years of manufacturing technical assistance services to be performed conus and oconus in support of the m1a1 tank production effort at the egyptian tank plant.
# 4013                                                                                                                                                                          igf::ot::igf stryker - nbcrv opt yr 1
# 4223                                        igf::ot::igf modification for addition of integrating a sample probe into the ngcd msid and integration onto the stryker; extending blind test in brassboard by 2 weeks
# 4393                                                                                                                                            igf::ot::igf incremental funding for clin 0009, stryker requirement
# 4630                                                                                                                                                              fiber installation at abrams theater igf::ot::igf
# 4703                                                                                                                                                   igf::ot::igf predictive analytics assessment for abrams tank
# 5030                                                                                          igf::ot::igf various pol repairs and repairs api tanks nebraska ang, ne; fort wayne ang, in; and battle creek ang, mi
# 5306                                                                        the purpose of mod p00083 is to incorporate work directives 1023 (light weight structures) and 2070 (4id abrams fsr-conus) igf::ot::igf
# 5812                                                                  the purpose of mod p00084 to incorporate work directive 2078 (3id abrams fsr-conus) and to fix an admin pron error on clin 2076. igf::ot::igf
# 6664                                                                                                                                                               igf::ot::igf dvl iii stryker reality integration
# 6668                                                                                                                                                               igf::ot::igf dvl iii stryker reality integration
# 6879                                                                          igf::ot::igf this modification adds option hours and materials costs to work directive gda-001r3 for the development of abrams armor.
# 7009                                                                       the purpose of this modification is to extend the contract pop to 28 feb 2017 and fund wd 2086 for korea abrams fsr-oconus. igf::ot::igf
#
#                                                                                                   PSC_Name  \
# 755                                                (J099) MAINT/REPAIR/REBUILD OF EQUIPMENT- MISCELLANEOUS
# 1611                                                   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL
# 2167                         (J016) MAINT/REPAIR/REBUILD OF EQUIPMENT- AIRCRAFT COMPONENTS AND ACCESSORIES
# 2596                                                      (Z1EE) MAINTENANCE OF TANK AUTOMOTIVE FACILITIES
# 2828  (J042) MAINT/REPAIR/REBUILD OF EQUIP- FIRE FIGHTING/RESCUE/SAFETY EQUIP; ENVIRON PROTECT EQUIP/MATLS
# 3499                           (AC93) R&D- DEFENSE SYSTEM: MISCELLANEOUS HARD GOODS (ADVANCED DEVELOPMENT)
# 3749                                                   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL
# 3797                                                        (L099) TECHNICAL REPRESENTATIVE- MISCELLANEOUS
# 4013                                                   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL
# 4223                           (AC93) R&D- DEFENSE SYSTEM: MISCELLANEOUS HARD GOODS (ADVANCED DEVELOPMENT)
# 4393                           (AC93) R&D- DEFENSE SYSTEM: MISCELLANEOUS HARD GOODS (ADVANCED DEVELOPMENT)
# 4630                                        (Z2AB) REPAIR OR ALTERATION OF CONFERENCE SPACE AND FACILITIES
# 4703                                                   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL
# 5030                                                          (Z1NA) MAINTENANCE OF FUEL SUPPLY FACILITIES
# 5306                                                   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL
# 5812                                                   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL
# 6664                                               (AD93) R&D- DEFENSE OTHER: OTHER (ADVANCED DEVELOPMENT)
# 6668                                               (AD93) R&D- DEFENSE OTHER: OTHER (ADVANCED DEVELOPMENT)
# 6879                (AC42) R&D- DEFENSE SYSTEM: TANK/AUTOMOTIVE (APPLIED RESEARCH/EXPLORATORY DEVELOPMENT)
# 7009                                                   (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL
#
#      code igf      GCS
# 755     J  ot  stryker
# 1611    R  ot  bradley
# 2167    J  ot  stryker
# 2596    Z  ot   abrams
# 2828    J  ot  stryker
# 3499    A  ot  stryker
# 3749    R  ot   abrams
# 3797    L  ot   abrams
# 4013    R  ot  stryker
# 4223    A  ot  stryker
# 4393    A  ot  stryker
# 4630    Z  ot   abrams
# 4703    R  ot   abrams
# 5030    Z  ot   abrams
# 5306    R  ot   abrams
# 5812    R  ot   abrams
# 6664    A  ot  stryker
# 6668    A  ot  stryker
# 6879    A  ot   abrams
# 7009    R  ot   abrams

# %% [markdown]
# These seem to be funding increases, for the most part. What is the total sum of CT?

# %%
ct.Awarded_Amount.sum() #183m
# Out:
# 183011789.42

# %% [markdown]
# It's interesting to see two oil spills in this list.Lets do a quick check on environmental remediation efforts  that are tied to GCS.

# %%
env = df[df['psc']=='F108']
env[['Fiscal_Year','Title','PSC_Name','GCS']].head(20)
# Out:
#        Fiscal_Year                                           Title  \
# 17075         2017  igf::ct::igf stryker fuel spill cleanup on i-5
# 20971         2017  igf::ct::igf stryker fuel spill cleanup on i-5
#
#                                                                  PSC_Name  \
# 17075  (F108) ENVIRONMENTAL SYSTEMS PROTECTION- ENVIRONMENTAL REMEDIATION
# 20971  (F108) ENVIRONMENTAL SYSTEMS PROTECTION- ENVIRONMENTAL REMEDIATION
#
#            GCS
# 17075  stryker
# 20971  stryker

# %% [markdown]
# Okay good! It's only stryker. How much did it cost?

# %%
env.Awarded_Amount.sum() #4k
# Out:
# 4079.33

# %% [markdown]
# Let's dig into training aids some more

# %%
tr = df[df['code']=='69']
tr[['Fiscal_Year','Title','PSC_Name', 'Awarded_Amount','GCS']].head(10)
# Out:
#        Fiscal_Year  \
# 2336          2016
# 2345          2016
# 6599          2016
# 10244         2016
# 10643         2017
# 11078         2016
# 11278         2016
# 11430         2016
# 12892         2017
# 13897         2017
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Title  \
# 2336                                                                                                                                                                                                                                                                                                           the contract awards sts services to oasis to modify, revise, and update the common software library for the m1 abrams tank and the bradley fighting vehicle.
# 2345                                                                                                                                                                                                                                                                                                                                                                                                                                  stryker mgs mobile agts pop extension
# 6599                                                                                                                                                                                                                                                                                                                                                                                               stryker semitendinosus tendon, tibialis tendon anterior, gracilis tendon
# 10244                   m1a1 mobile platoon agts - extend the pop for slins 0003aa, 0003ab and 0003ac at no cost to allow the contractor to provide a plan on how they intend to fulfill outstanding terms and conditions to "design, develop, procure, integrate, and test the hardware and software required to supply one (1) tdt that replicates driver operations in accordance with the m1a1 tank driver trainer (tdt) specification as approved in the tim and ipts.
# 10643                                                                                                                                                                                                                                                                                                                                                     stryker mobile gun system (mgs) advanced gunnery training system (agts) gunnery maual tc 3-20.31 software upgrade
# 11078  pm gctt has a requirement to upgrade the stryker maintenance training system (mts) software by converting the lessons on the diagnostic troubleshooting trainer (dtt) from a 2-d format to a 3-d format. w900kk-09-d-0562 delivery order 0002 was awarded to design and develop maintenance lessons in 3-d format for the stryker mobile gun system (mgs). this requirement will deliver the conversion of the current lessons that are 2-d to a 3-d graphic design.
# 11278                                                                                                                                                                                                                                                                                                                                                                                                                                         i-miles cvtess system bradley
# 11430                                                                                                                                                                                                                                                                                                                                                                                                                                         i-miles cvtess system bradley
# 12892                                                                                                                                                                                                                                                                                                                                                     stryker mobile gun system (mgs) advanced gunnery training system (agts) gunnery maual tc 3-20.31 software upgrade
# 13897                                                                                                                                                                                                                                                                                                                                                                igf::ot::igf services-priced. abrams csl upgrade ordering period 09 december 2016 to 08 december 2017.
#
#                                PSC_Name  Awarded_Amount      GCS
# 2336               (6910) TRAINING AIDS      2354569.75  general
# 2345   (6920) ARMAMENT TRAINING DEVICES            0.00  stryker
# 6599               (6910) TRAINING AIDS        39575.00  stryker
# 10244              (6910) TRAINING AIDS            0.00   abrams
# 10643    (69) TRAINING AIDS AND DEVICES            0.00  stryker
# 11078              (6910) TRAINING AIDS      4442412.00  stryker
# 11278              (6910) TRAINING AIDS     -1179955.66  bradley
# 11430              (6910) TRAINING AIDS      1984313.66  bradley
# 12892    (69) TRAINING AIDS AND DEVICES            0.00  stryker
# 13897              (6910) TRAINING AIDS      1310400.00   abrams

# %% [markdown]
# Main training for each:
#
# i-miles cvtess = Bradley (later adding Abrams in 2020) |
# mgs mobile agts = Stryker |
# ed/tt(ft benning) = Abrams

# %%
df['train'] =  np.where(df.Title.str.contains("i-miles cvtess"), 'bradley',
                   np.where(df.Title.str.contains("mgs mobile agts"),"stryker",  
                     np.where(df.Title.str.contains("ed/tt"),"abrams",        
                            np.NaN)))

# %%
train = df[['train','Title','award_gain']]

train.groupby('train').sum()
# Out:
# C:\Users\kalia\AppData\Local\Temp\ipykernel_44072\3850486589.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   train.groupby('train').sum()
#            award_gain
# train
# abrams   1.700237e+07
# bradley  2.164841e+06
# nan      8.030386e+09
# stryker  0.000000e+00

# %% [markdown]
# Looking at Contracting Offices, Top Vendors

# %%
q8 = "SELECT Contracting_Office as co, sum(Awarded_Amount) as aa FROM df GROUP BY co ORDER BY aa desc;"
pysqldf(q8).head(10)
# Out:
#                                                                                                  co  \
# 0                                                              0646 AQ TM     CONTRACTING TEA - APO
# 1                                                                         US Department of the Army
# 2                                                                                 DLA Land - Warren
# 3                                                                     ACC-APG Aberdeen - Division C
# 4                                                      ACC New Jersey Contracting Center (ACC-PICA)
# 5                                                                               ACC-APG Orlando, FL
# 6                                                                           ACC Contracting Centers
# 7                                                                               DLA Land - Aberdeen
# 8          ACC Aberdeen Proving Ground Contracting Center (ACC-APG) (includes former Fort Monmouth)
# 9  Defense Microelectronics Activity (DMEA) (formerly Advanced Microelectronics Section under USAF)
#
#              aa
# 0  6.017419e+09
# 1  9.846085e+08
# 2  3.723811e+08
# 3  2.451065e+08
# 4  9.664224e+07
# 5  7.658229e+07
# 6  3.782974e+07
# 7  3.091885e+07
# 8  1.968142e+07
# 9  1.767431e+07

# %%
df['co'] = np.where(df.Contracting_Office.str.contains("DLA Land"), 'DLA',
                   np.where(df.Contracting_Office.str.contains("ACC"), 'ACC',
                     np.where(df.Contracting_Office.str.contains("US Department of the Army"), "Army",
                        np.where(df.Contracting_Office.str.contains("0646 AQ TM"), 'APO',
                            np.NaN))))

# %%
co= df[['co','Awarded_Amount']]

co.groupby('co').sum()
# Out:
#       Awarded_Amount
# co
# ACC     4.870232e+08
# APO     6.017419e+09
# Army    9.846085e+08
# DLA     4.038241e+08
# nan     5.317751e+07

# %%
q9 = "SELECT co, ven_name, sum(Awarded_Amount) as aa FROM df GROUP BY co, ven_name ORDER BY aa desc;"
pysqldf(q9).head(10)
# Out:
#      co                                   ven_name            aa
# 0   APO                generaldynamicslandsystemss  4.653279e+09
# 1  Army                generaldynamicslandsystemss  8.564627e+08
# 2   APO                  baesystemslandarmamentslp  5.443362e+08
# 3   APO                      systemsdrssustainment  3.141607e+08
# 4   ACC  raytheonlockheedmartinjavelinjointventure  2.011158e+08
# 5   DLA                generaldynamicslandsystemss  1.742751e+08
# 6   APO                        allisontransmission  1.673401e+08
# 7   APO                     honeywellinternational  1.270323e+08
# 8   APO                             l3technologies  8.928452e+07
# 9   ACC                kongsbergdefenceaerospaceas  8.686852e+07

# %% [markdown]
# Looking at top vendors for top PSC

# %%
df['psctop'] = np.where(df.code.str.contains("R"), 'support',
                    np.where(df.code.str.contains("25"), 'veh comp',
                              np.where(df.psc.str.contains("4855"), 'night vis',
                                    np.where(df.code.str.contains("J"), 'maint',
                                       np.where(df.code.str.contains("A"), 'RD',
                                               np.where(df.code.str.contains("U"), 'edu', 
                            np.NaN))))))

# %%
q10 = "SELECT psctop, ven_name, sum(Awarded_Amount) as aa FROM df WHERE psctop='night vis' GROUP BY psctop, ven_name  ORDER BY aa desc;"
pysqldf(q10).head(70)
# Out:
# Empty DataFrame
# Columns: [psctop, ven_name, aa]
# Index: []

# %%
support = df[df['psc']== 'R425']

support.Title.value_counts()
# Out:
# contract w56hzv-17-c-0067 is a sole source contract to general dynamics land systems (gdls) for the acquisition of system technical support (sts) and sustainment system technical support (ssts) services. sts and ssts services consist of engineering and logistics services to the abrams family of vehicles (fov).                                                                                          68
# stryker contractor test support                                                                                                                                                                                                                                                                                                                                                                                  35
# systems technical support and sustainment systems technical support services, consisting of engineering, logistics, and fielding support for the bradley fighting vehicle family of vehicles, the multiple launch rocket system carrier, and the m113 armored personnel carrier family of vehicles.                                                                                                              15
# stryker logistics engineering support year 3                                                                                                                                                                                                                                                                                                                                                                     12
# stryker logistics engineering support                                                                                                                                                                                                                                                                                                                                                                            10
#                                                                                                                                                                                                                                                                                                                                                                                                                  ..
# degraded visual environment (dve) cyber support, ndte ais cybersecurity support, abrams m1a2 systems enhanced package v3 tank, mda software assurance process support, mounted mission command v1                                                                                                                                                                                                                 1
# contract w56hzv-17-c-0067 is a sole source contract to general dynamics land systems (gdls) for the acquisition of system technical support (sts) and sustainment system technical support (ssts) services. sts and ssts services consist of engineering and logistics services to the abrams family of vehicles (fov). this modification is to incorporate supplement 1 work directive 4191 to the contract.     1
# extending the period of performance for the various support services - stryker panel.                                                                                                                                                                                                                                                                                                                             1
# m1a1 abrams tank fire control system, obsolescence                                                                                                                                                                                                                                                                                                                                                                1
# programmatic support to mst/pfal, programmatic support for the stryker virtual collective trainer (svct)                                                                                                                                                                                                                                                                                                          1
# Name: Title, Length: 208, dtype: int64

# %%
maint = df[df['code']=='J']

maint = maint[['Title', 'Awarded_Amount']]

maint.groupby('Title').sum()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Awarded_Amount
# Title
# abrams                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            -190758.32
# award contract line item number 0211 for program manager bradley support on task order 0019 (gmdt). gunnery maintenance and device trainers (gmdt) provides training and technical assistance to the gunnery, maintenance, and driver trainers (gmdt) family of devices to include, but not limited to the following devices: bradley advanced training system (bats); conduct of fire trainer (coft) family of devices; army advanced gunnery training system (agts) family of devices; common driver trainer (cdt) family of devices; abrams, bradley, and stryker maintenance training system (mts); construction equipment virtual trainers (cevt); and gunnery and maintenance desktop trainers for on demand device support across the gmdt portfolio.        28513.00
# award contract line items 0075, 0076, 0077 for task order 0019 depot support (gmdt). gunnery maintenance and device trainers (gmdt) provides training and technical assistance to the gunnery, maintenance, and driver trainers (gmdt) family of devices to include, but not limited to the following devices: bradley advanced training system (bats); conduct of fire trainer (coft) family of devices; army advanced gunnery training system (agts) family of devices; common driver trainer (cdt) family of devices; abrams, bradley, and stryker maintenance training system (mts); construction equipment virtual trainers (cevt); and gunnery and maintenance desktop trainers for on demand device support across the gmdt portfolio.                      168516.00
# base contract support for annual stryker retrofit activity in various locations.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  5966047.00
# contractor support for government testing of fbh and dvh strykers at various government test sites.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               -193223.00
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# three year team armor program (tap)contract to include one base year with two option periods for 12-months each for the receipt, inspection, testing, diagnosis, repair, storage, issue parts in support of abrams, bradley and wolverine vehicles.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              14305951.70
# wd r-11-02-01 and r-11-04-01 for stryker retrofits in vilseck germany and ft. carson, mo.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          222115.00
# wd r-11-10-10 for stryker retrofits in ft. pickett, va.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             23056.00
# wd r-11-12-01 is for retrofit activity on stryker variants performed at fort leonardwood, mo.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       45116.00
# work directive r-11-13-02 award for retrofit activity performed at jblm on stryker variants.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        13616.00
#
# [101 rows x 1 columns]

# %%
edu = df[df['code']=='U']

edu = edu[['Awarded_Amount', 'PSC_Name']]

edu.groupby('PSC_Name').sum()
# Out:
#                                                             Awarded_Amount
# PSC_Name
# (U008) EDUCATION/TRAINING- TRAINING/CURRICULUM DEVELOPMENT    3.178150e+04
# (U009) EDUCATION/TRAINING- GENERAL                            1.500212e+04
# (U013) EDUCATION/TRAINING- COMBAT                             1.372642e+08
# (U099) EDUCATION/TRAINING- OTHER                             -5.986748e+04

# %%
support = df[df['award_loss']< 0 ]

support[['Title', 'code', 'award_loss']].head(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Title  \
# 1672                                                                                                                                                                                                   the purpose of this modification is to implement the following changes to the contract: a. add 108 ea rear sentry seats, p/n 10695231-110 to the icv-icvv reclaim list (attachment 0083). b. obtain a credit in the amount of $389,448 against the dvh stryker exchange infantry carrier vehicle (xicvvs) clins 0601ca, 0601cb and 0601cc to account for the 108 ea rear sentry seats, p/n 10695231-110 being reclaimed in the exchange process. c. obtain a credit against clin 0601ca for the srat ii packaging issue and the exchange parts for which the contractor was unable to furnish under the exchange firm fixed price in the amount of $418,298. please reference pco letters sjb408, sjb409, sjb410, rkb136, rkb138, rkb147 and the srat ii packaging credit email, dated 14 may 2015.
# 1794                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            noun: wiring harness, bran. nsn: 6150-01-465-3770. part number: 12388468-3. quantity: 138 each. vehicle: tank, abrams, m1a2 unique. modification extends the delivery schedule date of the purchase order.
# 2720                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               cable and conduit a for dsests and will be utilized on the m1a1 (4000 characters) abrams and bradley. nsn 6150014786962
# 3327                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             igf::ct::igf decrease funding to remove expired funds for stryker program option year six
# 4013                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 igf::ot::igf stryker - nbcrv opt yr 1
# 6246                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  engineering design, development, integration, and test of cummins 675hp engine in support of the bradley ecp effort.
# 7287                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          igf::ot::igf modification for tower 3 temp tanks design and to deduct work at tower 3 repair water towers at nsf indian head
# 7296                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 igf::ct::igf decrease funding on aec's omnibus contract that supports the stryker program. base - labor (months 1-12)
# 7525                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          gunner restraint system (delta) for the stryker icv double v
# 9673  4605 - ngats - next generation automatic test set - limited user test 2. the ngats v6 is intended to be the newest off-platform automatic test system (ats) in the army integrated family of test equipment (ifte) product line that will provide the soldier a weapon system diagnostic tool. the ngats v6 is the replacement for the aging direct support system test set (dsests), by providing diagnostic support for current weapons system platforms supported by dsests which supports the abram and bradley platforms, the base shop test facility (bstf)(v)3, and bstf(v)5 which supports aviation and ground missile system. the bstf (v) 3, and bstf (v) 5 capability will each be added incrementally as pre-planned product improvements (p3i). up-armored m1085 medium tactical vehicle (mtv) as the prime mover. ngats was supported under the test support contract (tsc), which is a cost plus award fee indefinite delivery indefinite quantity (id-iq) contract w9115u-07-d-0003.
#
#      code  award_loss
# 1672   23  -823353.00
# 1794   61     -877.68
# 2720   61    -6640.00
# 3327    R   -10756.32
# 4013    R   -57274.06
# 6246   28  -223391.49
# 7287    Z  -438524.08
# 7296    H   -38197.94
# 7525   23     -285.13
# 9673    R    -3404.48

# %% [markdown]
# One concern is PoP extension. Lets see how often this happened.

# %%
df['pop'] = np.where(df.Title.str.contains("pop"), 'pop', np.nan)

df['pop'].value_counts()
# Out:
# nan    1634
# pop      13
# Name: pop, dtype: int64

# %% [markdown]
# There are 13 PoP comments. Lets see more about them.

# %%
pop = df[df['pop']=='pop']

pop = pop[['Title', 'Modification_Number', 'Contract_Number', 'Fiscal_Year', 'ven_name', 'Awarded_Amount', 'PSC_Name']]

pop.head(13)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Title  \
# 2203                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     modification to the current stryker test delivery order to extend the pop on clin 0423aj at no additional cost to the government.
# 2345                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 stryker mgs mobile agts pop extension
# 5092   1. this is a bilateral modification pursuant to mutual agreement. 2. the purpose of modification 65 to contract w56hzv-13-d-0008 is to clarify the period-of-performance (pop) for engineering support in production (esip) ordered under dvh stryker vehicle subclins identified below: (a) 0601ba- quantity of 24 - dvh stryker exchange infantry carrier vehicles (xicvvs); (b) 0601ca- quantity of 45 - dvh stryker exchange infantry carrier vehicles (xicvvs); (c) 0601cb- quantity of 5 - dvh stryker exchange infantry carrier vehicles (xicvvs); (d) 0601cc- quantity of 4 - dvh stryker exchange infantry carrier vehicles (xicvvs); (e) 0602ba- quantity of 28 - dvh stryker exchange mortar carrier vehicles (xmcvvs); (f) 0602ca- quantity of 17 - dvh stryker exchange mortar carrier vehicles (xmcvvs); (g) 0603ba- quantity of 17 - dvh stryker exchange commanders vehicles (xcvvs); (h) 0603ca- quantity of 22 - dvh stryker exchange commanders vehicles (xcvvs); (i) 0604ba- quantity of 5 - dvh stryker fire support vehicles (xfsvvs); (j) 0604ca- quantity of 7 - dvh stryker fire support vehicles (xfsvvs); (k) 0605ca- quantity of 5 - dvh stryker exchange engineer squad vehicles (xesvvs); (l) 0605cb- quantity of 10 - dvh stryker exchange engineer squad vehicles (xesvvs); (m) 0606ba- quantity of 19 - dvh stryker exchange medical evacuation vehicles (xmevvs); (n) 0606ca- quantity of 5 - dvh stryker exchange medical evacuation vehicles (xmevvs); (o) 0606cb- quantity of 6 - dvh stryker exchange medical evacuation vehicles (xmevvs); (p) 0606cd- quantity of 12 - dvh stryker exchange medical evacuation vehicles (xmevvs); (q) 0607ca- quantity of 6 - dvh stryker exchange anti-tank guided missile vehicles (xatvvs); (r) 0607cb- quantity of 8 - dvh stryker exchange anti-tank guided missile vehicles (xatvvs).
# 7009                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              the purpose of this modification is to extend the contract pop to 28 feb 2017 and fund wd 2086 for korea abrams fsr-oconus. igf::ot::igf
# 10244                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  m1a1 mobile platoon agts - extend the pop for slins 0003aa, 0003ab and 0003ac at no cost to allow the contractor to provide a plan on how they intend to fulfill outstanding terms and conditions to "design, develop, procure, integrate, and test the hardware and software required to supply one (1) tdt that replicates driver operations in accordance with the m1a1 tank driver trainer (tdt) specification as approved in the tim and ipts.
# 33504                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    base contract: stryker class requirements contract. task order: 0031: established for fy15 reset services. mod 11 to 0031: issued to extend delivery schedule for 2 mgs vehicles and pop for reset line shutdown.
# 35457                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   abrams sts. sole source to general dynamics land system. extending pop dates, funding overruns, and making administrative changes.
# 36393                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  stryker sts - pm yr 3 pop extension
# 37684                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       abrams sts funding increase and pop extension.
# 44717                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         period of performance (pop) extensions on labor&material sil relocation clins, and fund phase 2 sil maintenance labor effort under stryker sts sil contract.
# 45334                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               tiger abrams engine contract, administrative mod to incorporate pop ext. on clins and nsn corrections.
# 48164                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 tiger abrams engine contract administration modification to correct nsn corrections, pop extension, unit correction.
# 48311                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        vismod t-72 main battle tank modification to extend training contract line item period of performance (pop)due to excusable delays caused by corona virus disease (covid-19).
#
#       Modification_Number Contract_Number  Fiscal_Year  \
# 2203                   11   W56HZV13D0008         2016
# 2345                   13   W900KK09D0314         2016
# 5092                   65   W56HZV13D0008         2016
# 7009               P00087             NaN         2016
# 10244              P00011             NaN         2016
# 33504                  11   W56HZV13D0008         2018
# 35457              P00069             NaN         2019
# 36393                   1   W56HZV16D0037         2019
# 37684              P00078             NaN         2019
# 44717              P00004   W56HZV19D0046         2020
# 45334              P00119             NaN         2020
# 48164              P00124             NaN         2020
# 48311              P00004             NaN         2020
#
#                                         ven_name  Awarded_Amount  \
# 2203                 generaldynamicslandsystemss        12831.00
# 2345   raytheonlockheedmartinjavelinjointventure            0.00
# 5092                 generaldynamicslandsystemss        12831.00
# 7009                 generaldynamicslandsystemss       149948.00
# 10244  raytheonlockheedmartinjavelinjointventure            0.00
# 33504                generaldynamicslandsystemss        12831.00
# 35457                generaldynamicslandsystemss      2118426.00
# 36393                generaldynamicslandsystemss       141212.00
# 37684                generaldynamicslandsystemss     46249658.00
# 44717                generaldynamicslandsystemss       211835.00
# 45334                     honeywellinternational       101665.62
# 48164                     honeywellinternational       101665.62
# 48311                                    westefx            0.00
#
#                                                                                                       PSC_Name
# 2203                                                    (2355) COMBAT, ASSAULT, AND TACTICAL VEHICLES, WHEELED
# 2345                                                                          (6920) ARMAMENT TRAINING DEVICES
# 5092                                                    (2355) COMBAT, ASSAULT, AND TACTICAL VEHICLES, WHEELED
# 7009                                                       (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL
# 10244                                                                                     (6910) TRAINING AIDS
# 33504                                                   (2355) COMBAT, ASSAULT, AND TACTICAL VEHICLES, WHEELED
# 35457                                                      (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL
# 36393                                                      (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL
# 37684                                                      (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL
# 44717                                                      (R425) SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL
# 45334  (2835) GAS TURBINES AND JET ENGINES; NON-AIRCRAFT PRIME MOVER, AIRCRAFT NON-PRIME MOVER, AND COMPONENTS
# 48164  (2835) GAS TURBINES AND JET ENGINES; NON-AIRCRAFT PRIME MOVER, AIRCRAFT NON-PRIME MOVER, AND COMPONENTS
# 48311                                                                                     (6910) TRAINING AIDS
